# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../results/logs/fixed_rule_seed5/monitor.csv',skiprows=1)

# %%
df.head()
# Out:
#        r    l         t  true_completion_rate  cheat_rate  report_rate  \
# 0  -0.35  150  4.624480              0.294118    0.428571     0.411765
# 1  -2.20  150  4.858467              0.090909    0.500000     0.181818
# 2  -8.95  150  5.091086              0.000000    1.000000     0.066667
# 3 -12.95  150  5.324635              0.071429    0.000000     0.000000
# 4  -3.30  150  5.583364              0.307692    0.000000     0.076923
#
#    audit_prob  steps_taken
# 0         0.4          150
# 1         0.4          150
# 2         0.4          150
# 3         0.4          150
# 4         0.4          150

# %%
df.shape
# Out:
# (4000, 8)

# %%
df['report_rate'].rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
# plotting cheat rate and r over time
#df['cheat_rate'].groupby(df.index // 100).mean().plot()
df['cheat_rate'].rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
df['r'].rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
df['report_rate'].rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
df['audit_prob'].rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
df2=pd.read_csv('../results/position_log.csv')
